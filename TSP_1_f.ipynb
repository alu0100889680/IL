# %% [markdown]
# <a href="https://colab.research.google.com/github/alu0100889680/IL/blob/master/TSP_1_f.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pulp
import random
import math
import time 
from pulp import *
import matplotlib.pyplot as plt

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

  
# NUMERO DE NODOS
n = 10
nodosv = range(0,n)
uno = range(1,n)

random.seed(1111) 

# VECTOR DE DISTANCIAS
dist = {}
for i in nodosv:
  for j in nodosv:
    if i!=j:
      dist[i,j] = 0

for i in nodosv:
    for j in nodosv:
      if i!=j:
        if dist[i,j] == 0:
          aux = random.randint(1,100)
          dist[i,j] = aux
          dist[j,i] = aux
          
m = pulp.LpProblem('TSP', pulp.LpMinimize)

# VARIABLES
x =  {}
for i in nodosv:
    for j in nodosv:
        lowerBound = 0
        upperBound = 1

        if i == j:
            upperBound = 0

        x[i,j] = pulp.LpVariable('x(' + str(i) + ',' + str(j) + ')', lowerBound, upperBound, pulp.LpBinary)
  
    
f =  {}
for i in nodosv:
    for j in nodosv:
        f[i,j] = pulp.LpVariable('f(' + str(i) + ',' + str(j) + ')', cat='Integer')

  
# FUNCION OBJETIVO
m += pulp.lpSum([dist[i,j] * x[i,j] for i in nodosv for j in nodosv if i!=j])

# RESTRICCIONES
for i in nodosv:
  m += pulp.lpSum([x[i,j] for j in nodosv if i!=j]) == 1
  
for i in nodosv:
  m += pulp.lpSum([x[j,i] for j in nodosv if i!=j]) == 1
  
for i in uno:
  m += pulp.lpSum([f[j,i] - f[i,j] for j in nodosv if i!=j]) == 1
  
for i in nodosv:
  for j in nodosv:
    if i!=j:
      m += pulp.lpSum([f[i,j]]) <= (n-1)*x[i,j]
      m += pulp.lpSum([f[i,j]]) >= 0

# EJECUCIÓN Y MEDICIÓN DEL TIEMPO
t0 = time.time()
status = m.solve()
dif = time.time() - t0

print(color.BOLD + color.PURPLE + color.UNDERLINE + 'TSP - Modelo con variable f_ij' + color.END + '\n')

# SOLUCIÓN Y DATOS       
if(LpStatus[m.status] == "Optimal"):
  print(color.BOLD + 'Solución:' + color.END + ' Óptima')
  
else:
  print("Solución: No existe solución óptima")
print(color.BOLD + 'Descripción de la ruta óptima ordenada:' + color.END + '\n')

# ORDENAR LA RUTA
soluciones = []
for i in nodosv:
  for j in nodosv:
    if pulp.value(x[i,j]):
      soluciones.append([i,j])
      

orde = []
i = 0
for a in range(0,len(soluciones)):
  for j in nodosv:
    aux =  [i,j]
    if aux in soluciones:
      orde.append([i,j])
      i = j
  if(a == len(soluciones)):
    orde.append([i,0])

    
# FORMATEAR LA RUTA POR PANTALLA
for inx in range(0,n):
  i,j = orde[inx]
  print('Del punto ' + str(i) + ' al punto ' + str(j) + ': ' + str( pulp.value(dist[i,j]))  + ' metros')
print('\n')
    
total_cost = pulp.value(m.objective)
  
print (color.BOLD + 'Coste total de la ruta: ' + color.END +  str(total_cost) +  ' metros')
print("--------------------------------")

print(color.BOLD + 'Ejecutado en ' + color.END +  str(round(dif,4)) + ' segundos \n\n')

print(color.BOLD + 'Detalles del modelo: \n' + color.END)
print(m)
# Out:
# TSP - Modelo con variable f_ij
#
# Solución: Óptima
# Descripción de la ruta óptima ordenada:
#
# Del punto 0 al punto 9: 11 metros
# Del punto 9 al punto 5: 16 metros
# Del punto 5 al punto 1: 12 metros
# Del punto 1 al punto 7: 44 metros
# Del punto 7 al punto 8: 2 metros
# Del punto 8 al punto 2: 23 metros
# Del punto 2 al punto 3: 14 metros
# Del punto 3 al punto 4: 6 metros
# Del punto 4 al punto 6: 17 metros
# Del punto 6 al punto 0: 19 metros
#
#
# Coste total de la ruta: 164.0 metros
# --------------------------------
# Ejecutado en 0.2316 segundos
#
#
# Detalles del modelo:
#
# TSP:
# MINIMIZE
# 28*x(0,1) + 26*x(0,2) + 45*x(0,3) + 98*x(0,4) + 83*x(0,5) + 19*x(0,6) + 47*x(0,7) + 58*x(0,8) + 11*x(0,9) + 28*x(1,0) + 94*x(1,2) + 65*x(1,3) + 24*x(1,4) + 12*x(1,5) + 77*x(1,6) + 44*x(1,7) + 85*x(1,8) + 88*x(1,9) + 26*x(2,0) + 94*x(2,1) + 14*x(2,3) + 57*x(2,4) + 19*x(2,5) + 81*x(2,6) + 73*x(2,7) + 23*x(2,8) + 35*x(2,9) + 45*x(3,0) + 65*x(3,1) + 14*x(3,2) + 6*x(3,4) + 48*x(3,5) + 62*x(3,6) + 37*x(3,7) + 45*x(3,8) + 40*x(3,9) + 98*x(4,0) + 24*x(4,1) + 57*x(4,2) + 6*x(4,3) + 28*x(4,5) + 17*x(4,6) + 82*x(4,7) + 67*x(4,8) + 75*x(4,9) + 83*x(5,0) + 12*x(5,1) + 19*x(5,2) + 48*x(5,3) + 28*x(5,4) + 59*x(5,6) + 46*x(5,7) + 56*x(5,8) + 16*x(5,9) + 19*x(6,0) + 77*x(6,1) + 81*x(6,2) + 62*x(6,3) + 17*x(6,4) + 59*x(6,5) + 61*x(6,7) + 77*x(6,8) + 18*x(6,9) + 47*x(7,0) + 44*x(7,1) + 73*x(7,2) + 37*x(7,3) + 82*x(7,4) + 46*x(7,5) + 61*x(7,6) + 2*x(7,8) + 58*x(7,9) + 58*x(8,0) + 85*x(8,1) + 23*x(8,2) + 45*x(8,3) + 67*x(8,4) + 56*x(8,5) + 77*x(8,6) + 2*x(8,7) + 38*x(8,9) + 11*x(9,0) + 88*x(9,1) + 35*x(9,2) + 40*x(9,3) + 75*x(9,4) + 16*x(9,5) + 18*x(9,6) + 58*x(9,7) + 38*x(9,8) + 0
# SUBJECT TO
# _C1: x(0,1) + x(0,2) + x(0,3) + x(0,4) + x(0,5) + x(0,6) + x(0,7) + x(0,8)
#  + x(0,9) = 1
#
# _C2: x(1,0) + x(1,2) + x(1,3) + x(1,4) + x(1,5) + x(1,6) + x(1,7) + x(1,8)
#  + x(1,9) = 1
#
# _C3: x(2,0) + x(2,1) + x(2,3) + x(2,4) + x(2,5) + x(2,6) + x(2,7) + x(2,8)
#  + x(2,9) = 1
#
# _C4: x(3,0) + x(3,1) + x(3,2) + x(3,4) + x(3,5) + x(3,6) + x(3,7) + x(3,8)
#  + x(3,9) = 1
#
# _C5: x(4,0) + x(4,1) + x(4,2) + x(4,3) + x(4,5) + x(4,6) + x(4,7) + x(4,8)
#  + x(4,9) = 1
#
# _C6: x(5,0) + x(5,1) + x(5,2) + x(5,3) + x(5,4) + x(5,6) + x(5,7) + x(5,8)
#  + x(5,9) = 1
#
# _C7: x(6,0) + x(6,1) + x(6,2) + x(6,3) + x(6,4) + x(6,5) + x(6,7) + x(6,8)
#  + x(6,9) = 1
#
# _C8: x(7,0) + x(7,1) + x(7,2) + x(7,3) + x(7,4) + x(7,5) + x(7,6) + x(7,8)
#  + x(7,9) = 1
#
# _C9: x(8,0) + x(8,1) + x(8,2) + x(8,3) + x(8,4) + x(8,5) + x(8,6) + x(8,7)
#  + x(8,9) = 1
#
# _C10: x(9,0) + x(9,1) + x(9,2) + x(9,3) + x(9,4) + x(9,5) + x(9,6) + x(9,7)
#  + x(9,8) = 1
#
# _C11: x(1,0) + x(2,0) + x(3,0) + x(4,0) + x(5,0) + x(6,0) + x(7,0) + x(8,0)
#  + x(9,0) = 1
#
# _C12: x(0,1) + x(2,1) + x(3,1) + x(4,1) + x(5,1) + x(6,1) + x(7,1) + x(8,1)
#  + x(9,1) = 1
#
# _C13: x(0,2) + x(1,2) + x(3,2) + x(4,2) + x(5,2) + x(6,2) + x(7,2) + x(8,2)
#  + x(9,2) = 1
#
# _C14: x(0,3) + x(1,3) + x(2,3) + x(4,3) + x(5,3) + x(6,3) + x(7,3) + x(8,3)
#  + x(9,3) = 1
#
# _C15: x(0,4) + x(1,4) + x(2,4) + x(3,4) + x(5,4) + x(6,4) + x(7,4) + x(8,4)
#  + x(9,4) = 1
#
# _C16: x(0,5) + x(1,5) + x(2,5) + x(3,5) + x(4,5) + x(6,5) + x(7,5) + x(8,5)
#  + x(9,5) = 1
#
# _C17: x(0,6) + x(1,6) + x(2,6) + x(3,6) + x(4,6) + x(5,6) + x(7,6) + x(8,6)
#  + x(9,6) = 1
#
# _C18: x(0,7) + x(1,7) + x(2,7) + x(3,7) + x(4,7) + x(5,7) + x(6,7) + x(8,7)
#  + x(9,7) = 1
#
# _C19: x(0,8) + x(1,8) + x(2,8) + x(3,8) + x(4,8) + x(5,8) + x(6,8) + x(7,8)
#  + x(9,8) = 1
#
# _C20: x(0,9) + x(1,9) + x(2,9) + x(3,9) + x(4,9) + x(5,9) + x(6,9) + x(7,9)
#  + x(8,9) = 1
#
# _C21: f(0,1) - f(1,0) - f(1,2) - f(1,3) - f(1,4) - f(1,5) - f(1,6) - f(1,7)
#  - f(1,8) - f(1,9) + f(2,1) + f(3,1) + f(4,1) + f(5,1) + f(6,1) + f(7,1)
#  + f(8,1) + f(9,1) = 1
#
# _C22: f(0,2) + f(1,2) - f(2,0) - f(2,1) - f(2,3) - f(2,4) - f(2,5) - f(2,6)
#  - f(2,7) - f(2,8) - f(2,9) + f(3,2) + f(4,2) + f(5,2) + f(6,2) + f(7,2)
#  + f(8,2) + f(9,2) = 1
#
# _C23: f(0,3) + f(1,3) + f(2,3) - f(3,0) - f(3,1) - f(3,2) - f(3,4) - f(3,5)
#  - f(3,6) - f(3,7) - f(3,8) - f(3,9) + f(4,3) + f(5,3) + f(6,3) + f(7,3)
#  + f(8,3) + f(9,3) = 1
#
# _C24: f(0,4) + f(1,4) + f(2,4) + f(3,4) - f(4,0) - f(4,1) - f(4,2) - f(4,3)
#  - f(4,5) - f(4,6) - f(4,7) - f(4,8) - f(4,9) + f(5,4) + f(6,4) + f(7,4)
#  + f(8,4) + f(9,4) = 1
#
# _C25: f(0,5) + f(1,5) + f(2,5) + f(3,5) + f(4,5) - f(5,0) - f(5,1) - f(5,2)
#  - f(5,3) - f(5,4) - f(5,6) - f(5,7) - f(5,8) - f(5,9) + f(6,5) + f(7,5)
#  + f(8,5) + f(9,5) = 1
#
# _C26: f(0,6) + f(1,6) + f(2,6) + f(3,6) + f(4,6) + f(5,6) - f(6,0) - f(6,1)
#  - f(6,2) - f(6,3) - f(6,4) - f(6,5) - f(6,7) - f(6,8) - f(6,9) + f(7,6)
#  + f(8,6) + f(9,6) = 1
#
# _C27: f(0,7) + f(1,7) + f(2,7) + f(3,7) + f(4,7) + f(5,7) + f(6,7) - f(7,0)
#  - f(7,1) - f(7,2) - f(7,3) - f(7,4) - f(7,5) - f(7,6) - f(7,8) - f(7,9)
#  + f(8,7) + f(9,7) = 1
#
# _C28: f(0,8) + f(1,8) + f(2,8) + f(3,8) + f(4,8) + f(5,8) + f(6,8) + f(7,8)
#  - f(8,0) - f(8,1) - f(8,2) - f(8,3) - f(8,4) - f(8,5) - f(8,6) - f(8,7)
#  - f(8,9) + f(9,8) = 1
#
# _C29: f(0,9) + f(1,9) + f(2,9) + f(3,9) + f(4,9) + f(5,9) + f(6,9) + f(7,9)
#  + f(8,9) - f(9,0) - f(9,1) - f(9,2) - f(9,3) - f(9,4) - f(9,5) - f(9,6)
#  - f(9,7) - f(9,8) = 1
#
# _C30: f(0,1) - 9 x(0,1) <= 0
#
# _C31: f(0,1) >= 0
#
# _C32: f(0,2) - 9 x(0,2) <= 0
#
# _C33: f(0,2) >= 0
#
# _C34: f(0,3) - 9 x(0,3) <= 0
#
# _C35: f(0,3) >= 0
#
# _C36: f(0,4) - 9 x(0,4) <= 0
#
# _C37: f(0,4) >= 0
#
# _C38: f(0,5) - 9 x(0,5) <= 0
#
# _C39: f(0,5) >= 0
#
# _C40: f(0,6) - 9 x(0,6) <= 0
#
# _C41: f(0,6) >= 0
#
# _C42: f(0,7) - 9 x(0,7) <= 0
#
# _C43: f(0,7) >= 0
#
# _C44: f(0,8) - 9 x(0,8) <= 0
#
# _C45: f(0,8) >= 0
#
# _C46: f(0,9) - 9 x(0,9) <= 0
#
# _C47: f(0,9) >= 0
#
# _C48: f(1,0) - 9 x(1,0) <= 0
#
# _C49: f(1,0) >= 0
#
# _C50: f(1,2) - 9 x(1,2) <= 0
#
# _C51: f(1,2) >= 0
#
# _C52: f(1,3) - 9 x(1,3) <= 0
#
# _C53: f(1,3) >= 0
#
# _C54: f(1,4) - 9 x(1,4) <= 0
#
# _C55: f(1,4) >= 0
#
# _C56: f(1,5) - 9 x(1,5) <= 0
#
# _C57: f(1,5) >= 0
#
# _C58: f(1,6) - 9 x(1,6) <= 0
#
# _C59: f(1,6) >= 0
#
# _C60: f(1,7) - 9 x(1,7) <= 0
#
# _C61: f(1,7) >= 0
#
# _C62: f(1,8) - 9 x(1,8) <= 0
#
# _C63: f(1,8) >= 0
#
# _C64: f(1,9) - 9 x(1,9) <= 0
#
# _C65: f(1,9) >= 0
#
# _C66: f(2,0) - 9 x(2,0) <= 0
#
# _C67: f(2,0) >= 0
#
# _C68: f(2,1) - 9 x(2,1) <= 0
#
# _C69: f(2,1) >= 0
#
# _C70: f(2,3) - 9 x(2,3) <= 0
#
# _C71: f(2,3) >= 0
#
# _C72: f(2,4) - 9 x(2,4) <= 0
#
# _C73: f(2,4) >= 0
#
# _C74: f(2,5) - 9 x(2,5) <= 0
#
# _C75: f(2,5) >= 0
#
# _C76: f(2,6) - 9 x(2,6) <= 0
#
# _C77: f(2,6) >= 0
#
# _C78: f(2,7) - 9 x(2,7) <= 0
#
# _C79: f(2,7) >= 0
#
# _C80: f(2,8) - 9 x(2,8) <= 0
#
# _C81: f(2,8) >= 0
#
# _C82: f(2,9) - 9 x(2,9) <= 0
#
# _C83: f(2,9) >= 0
#
# _C84: f(3,0) - 9 x(3,0) <= 0
#
# _C85: f(3,0) >= 0
#
# _C86: f(3,1) - 9 x(3,1) <= 0
#
# _C87: f(3,1) >= 0
#
# _C88: f(3,2) - 9 x(3,2) <= 0
#
# _C89: f(3,2) >= 0
#
# _C90: f(3,4) - 9 x(3,4) <= 0
#
# _C91: f(3,4) >= 0
#
# _C92: f(3,5) - 9 x(3,5) <= 0
#
# _C93: f(3,5) >= 0
#
# _C94: f(3,6) - 9 x(3,6) <= 0
#
# _C95: f(3,6) >= 0
#
# _C96: f(3,7) - 9 x(3,7) <= 0
#
# _C97: f(3,7) >= 0
#
# _C98: f(3,8) - 9 x(3,8) <= 0
#
# _C99: f(3,8) >= 0
#
# _C100: f(3,9) - 9 x(3,9) <= 0
#
# _C101: f(3,9) >= 0
#
# _C102: f(4,0) - 9 x(4,0) <= 0
#
# _C103: f(4,0) >= 0
#
# _C104: f(4,1) - 9 x(4,1) <= 0
#
# _C105: f(4,1) >= 0
#
# _C106: f(4,2) - 9 x(4,2) <= 0
#
# _C107: f(4,2) >= 0
#
# _C108: f(4,3) - 9 x(4,3) <= 0
#
# _C109: f(4,3) >= 0
#
# _C110: f(4,5) - 9 x(4,5) <= 0
#
# _C111: f(4,5) >= 0
#
# _C112: f(4,6) - 9 x(4,6) <= 0
#
# _C113: f(4,6) >= 0
#
# _C114: f(4,7) - 9 x(4,7) <= 0
#
# _C115: f(4,7) >= 0
#
# _C116: f(4,8) - 9 x(4,8) <= 0
#
# _C117: f(4,8) >= 0
#
# _C118: f(4,9) - 9 x(4,9) <= 0
#
# _C119: f(4,9) >= 0
#
# _C120: f(5,0) - 9 x(5,0) <= 0
#
# _C121: f(5,0) >= 0
#
# _C122: f(5,1) - 9 x(5,1) <= 0
#
# _C123: f(5,1) >= 0
#
# _C124: f(5,2) - 9 x(5,2) <= 0
#
# _C125: f(5,2) >= 0
#
# _C126: f(5,3) - 9 x(5,3) <= 0
#
# _C127: f(5,3) >= 0
#
# _C128: f(5,4) - 9 x(5,4) <= 0
#
# _C129: f(5,4) >= 0
#
# _C130: f(5,6) - 9 x(5,6) <= 0
#
# _C131: f(5,6) >= 0
#
# _C132: f(5,7) - 9 x(5,7) <= 0
#
# _C133: f(5,7) >= 0
#
# _C134: f(5,8) - 9 x(5,8) <= 0
#
# _C135: f(5,8) >= 0
#
# _C136: f(5,9) - 9 x(5,9) <= 0
#
# _C137: f(5,9) >= 0
#
# _C138: f(6,0) - 9 x(6,0) <= 0
#
# _C139: f(6,0) >= 0
#
# _C140: f(6,1) - 9 x(6,1) <= 0
#
# _C141: f(6,1) >= 0
#
# _C142: f(6,2) - 9 x(6,2) <= 0
#
# _C143: f(6,2) >= 0
#
# _C144: f(6,3) - 9 x(6,3) <= 0
#
# _C145: f(6,3) >= 0
#
# _C146: f(6,4) - 9 x(6,4) <= 0
#
# _C147: f(6,4) >= 0
#
# _C148: f(6,5) - 9 x(6,5) <= 0
#
# _C149: f(6,5) >= 0
#
# _C150: f(6,7) - 9 x(6,7) <= 0
#
# _C151: f(6,7) >= 0
#
# _C152: f(6,8) - 9 x(6,8) <= 0
#
# _C153: f(6,8) >= 0
#
# _C154: f(6,9) - 9 x(6,9) <= 0
#
# _C155: f(6,9) >= 0
#
# _C156: f(7,0) - 9 x(7,0) <= 0
#
# _C157: f(7,0) >= 0
#
# _C158: f(7,1) - 9 x(7,1) <= 0
#
# _C159: f(7,1) >= 0
#
# _C160: f(7,2) - 9 x(7,2) <= 0
#
# _C161: f(7,2) >= 0
#
# _C162: f(7,3) - 9 x(7,3) <= 0
#
# _C163: f(7,3) >= 0
#
# _C164: f(7,4) - 9 x(7,4) <= 0
#
# _C165: f(7,4) >= 0
#
# _C166: f(7,5) - 9 x(7,5) <= 0
#
# _C167: f(7,5) >= 0
#
# _C168: f(7,6) - 9 x(7,6) <= 0
#
# _C169: f(7,6) >= 0
#
# _C170: f(7,8) - 9 x(7,8) <= 0
#
# _C171: f(7,8) >= 0
#
# _C172: f(7,9) - 9 x(7,9) <= 0
#
# _C173: f(7,9) >= 0
#
# _C174: f(8,0) - 9 x(8,0) <= 0
#
# _C175: f(8,0) >= 0
#
# _C176: f(8,1) - 9 x(8,1) <= 0
#
# _C177: f(8,1) >= 0
#
# _C178: f(8,2) - 9 x(8,2) <= 0
#
# _C179: f(8,2) >= 0
#
# _C180: f(8,3) - 9 x(8,3) <= 0
#
# _C181: f(8,3) >= 0
#
# _C182: f(8,4) - 9 x(8,4) <= 0
#
# _C183: f(8,4) >= 0
#
# _C184: f(8,5) - 9 x(8,5) <= 0
#
# _C185: f(8,5) >= 0
#
# _C186: f(8,6) - 9 x(8,6) <= 0
#
# _C187: f(8,6) >= 0
#
# _C188: f(8,7) - 9 x(8,7) <= 0
#
# _C189: f(8,7) >= 0
#
# _C190: f(8,9) - 9 x(8,9) <= 0
#
# _C191: f(8,9) >= 0
#
# _C192: f(9,0) - 9 x(9,0) <= 0
#
# _C193: f(9,0) >= 0
#
# _C194: f(9,1) - 9 x(9,1) <= 0
#
# _C195: f(9,1) >= 0
#
# _C196: f(9,2) - 9 x(9,2) <= 0
#
# _C197: f(9,2) >= 0
#
# _C198: f(9,3) - 9 x(9,3) <= 0
#
# _C199: f(9,3) >= 0
#
# _C200: f(9,4) - 9 x(9,4) <= 0
#
# _C201: f(9,4) >= 0
#
# _C202: f(9,5) - 9 x(9,5) <= 0
#
# _C203: f(9,5) >= 0
#
# _C204: f(9,6) - 9 x(9,6) <= 0
#
# _C205: f(9,6) >= 0
#
# _C206: f(9,7) - 9 x(9,7) <= 0
#
# _C207: f(9,7) >= 0
#
# _C208: f(9,8) - 9 x(9,8) <= 0
#
# _C209: f(9,8) >= 0
#
# VARIABLES
# f(0,1) free Integer
# f(0,2) free Integer
# f(0,3) free Integer
# f(0,4) free Integer
# f(0,5) free Integer
# f(0,6) free Integer
# f(0,7) free Integer
# f(0,8) free Integer
# f(0,9) free Integer
# f(1,0) free Integer
# f(1,2) free Integer
# f(1,3) free Integer
# f(1,4) free Integer
# f(1,5) free Integer
# f(1,6) free Integer
# f(1,7) free Integer
# f(1,8) free Integer
# f(1,9) free Integer
# f(2,0) free Integer
# f(2,1) free Integer
# f(2,3) free Integer
# f(2,4) free Integer
# f(2,5) free Integer
# f(2,6) free Integer
# f(2,7) free Integer
# f(2,8) free Integer
# f(2,9) free Integer
# f(3,0) free Integer
# f(3,1) free Integer
# f(3,2) free Integer
# f(3,4) free Integer
# f(3,5) free Integer
# f(3,6) free Integer
# f(3,7) free Integer
# f(3,8) free Integer
# f(3,9) free Integer
# f(4,0) free Integer
# f(4,1) free Integer
# f(4,2) free Integer
# f(4,3) free Integer
# f(4,5) free Integer
# f(4,6) free Integer
# f(4,7) free Integer
# f(4,8) free Integer
# f(4,9) free Integer
# f(5,0) free Integer
# f(5,1) free Integer
# f(5,2) free Integer
# f(5,3) free Integer
# f(5,4) free Integer
# f(5,6) free Integer
# f(5,7) free Integer
# f(5,8) free Integer
# f(5,9) free Integer
# f(6,0) free Integer
# f(6,1) free Integer
# f(6,2) free Integer
# f(6,3) free Integer
# f(6,4) free Integer
# f(6,5) free Integer
# f(6,7) free Integer
# f(6,8) free Integer
# f(6,9) free Integer
# f(7,0) free Integer
# f(7,1) free Integer
# f(7,2) free Integer
# f(7,3) free Integer
# f(7,4) free Integer
# f(7,5) free Integer
# f(7,6) free Integer
# f(7,8) free Integer
# f(7,9) free Integer
# f(8,0) free Integer
# f(8,1) free Integer
# f(8,2) free Integer
# f(8,3) free Integer
# f(8,4) free Integer
# f(8,5) free Integer
# f(8,6) free Integer
# f(8,7) free Integer
# f(8,9) free Integer
# f(9,0) free Integer
# f(9,1) free Integer
# f(9,2) free Integer
# f(9,3) free Integer
# f(9,4) free Integer
# f(9,5) free Integer
# f(9,6) free Integer
# f(9,7) free Integer
# f(9,8) free Integer
# 0 <= x(0,1) <= 1 Integer
# 0 <= x(0,2) <= 1 Integer
# 0 <= x(0,3) <= 1 Integer
# 0 <= x(0,4) <= 1 Integer
# 0 <= x(0,5) <= 1 Integer
# 0 <= x(0,6) <= 1 Integer
# 0 <= x(0,7) <= 1 Integer
# 0 <= x(0,8) <= 1 Integer
# 0 <= x(0,9) <= 1 Integer
# 0 <= x(1,0) <= 1 Integer
# 0 <= x(1,2) <= 1 Integer
# 0 <= x(1,3) <= 1 Integer
# 0 <= x(1,4) <= 1 Integer
# 0 <= x(1,5) <= 1 Integer
# 0 <= x(1,6) <= 1 Integer
# 0 <= x(1,7) <= 1 Integer
# 0 <= x(1,8) <= 1 Integer
# 0 <= x(1,9) <= 1 Integer
# 0 <= x(2,0) <= 1 Integer
# 0 <= x(2,1) <= 1 Integer
# 0 <= x(2,3) <= 1 Integer
# 0 <= x(2,4) <= 1 Integer
# 0 <= x(2,5) <= 1 Integer
# 0 <= x(2,6) <= 1 Integer
# 0 <= x(2,7) <= 1 Integer
# 0 <= x(2,8) <= 1 Integer
# 0 <= x(2,9) <= 1 Integer
# 0 <= x(3,0) <= 1 Integer
# 0 <= x(3,1) <= 1 Integer
# 0 <= x(3,2) <= 1 Integer
# 0 <= x(3,4) <= 1 Integer
# 0 <= x(3,5) <= 1 Integer
# 0 <= x(3,6) <= 1 Integer
# 0 <= x(3,7) <= 1 Integer
# 0 <= x(3,8) <= 1 Integer
# 0 <= x(3,9) <= 1 Integer
# 0 <= x(4,0) <= 1 Integer
# 0 <= x(4,1) <= 1 Integer
# 0 <= x(4,2) <= 1 Integer
# 0 <= x(4,3) <= 1 Integer
# 0 <= x(4,5) <= 1 Integer
# 0 <= x(4,6) <= 1 Integer
# 0 <= x(4,7) <= 1 Integer
# 0 <= x(4,8) <= 1 Integer
# 0 <= x(4,9) <= 1 Integer
# 0 <= x(5,0) <= 1 Integer
# 0 <= x(5,1) <= 1 Integer
# 0 <= x(5,2) <= 1 Integer
# 0 <= x(5,3) <= 1 Integer
# 0 <= x(5,4) <= 1 Integer
# 0 <= x(5,6) <= 1 Integer
# 0 <= x(5,7) <= 1 Integer
# 0 <= x(5,8) <= 1 Integer
# 0 <= x(5,9) <= 1 Integer
# 0 <= x(6,0) <= 1 Integer
# 0 <= x(6,1) <= 1 Integer
# 0 <= x(6,2) <= 1 Integer
# 0 <= x(6,3) <= 1 Integer
# 0 <= x(6,4) <= 1 Integer
# 0 <= x(6,5) <= 1 Integer
# 0 <= x(6,7) <= 1 Integer
# 0 <= x(6,8) <= 1 Integer
# 0 <= x(6,9) <= 1 Integer
# 0 <= x(7,0) <= 1 Integer
# 0 <= x(7,1) <= 1 Integer
# 0 <= x(7,2) <= 1 Integer
# 0 <= x(7,3) <= 1 Integer
# 0 <= x(7,4) <= 1 Integer
# 0 <= x(7,5) <= 1 Integer
# 0 <= x(7,6) <= 1 Integer
# 0 <= x(7,8) <= 1 Integer
# 0 <= x(7,9) <= 1 Integer
# 0 <= x(8,0) <= 1 Integer
# 0 <= x(8,1) <= 1 Integer
# 0 <= x(8,2) <= 1 Integer
# 0 <= x(8,3) <= 1 Integer
# 0 <= x(8,4) <= 1 Integer
# 0 <= x(8,5) <= 1 Integer
# 0 <= x(8,6) <= 1 Integer
# 0 <= x(8,7) <= 1 Integer
# 0 <= x(8,9) <= 1 Integer
# 0 <= x(9,0) <= 1 Integer
# 0 <= x(9,1) <= 1 Integer
# 0 <= x(9,2) <= 1 Integer
# 0 <= x(9,3) <= 1 Integer
# 0 <= x(9,4) <= 1 Integer
# 0 <= x(9,5) <= 1 Integer
# 0 <= x(9,6) <= 1 Integer
# 0 <= x(9,7) <= 1 Integer
# 0 <= x(9,8) <= 1 Integer
